# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data.csv")
data.head()
# Out:
#    ID  Gender  Age_Group  Age  Marital_Status  Race  Religion  Tenure  \
# 0  A1       1        2.0   28               2     1         1       2
# 1  A2       2        1.0   25               2     1         1       2
# 2  A3       1        2.0   28               2     1         1       2
# 3  A4       2        2.0   30               2     1         1       3
# 4  A5       2        2.0   33               2     1         1       2
#
#    Highest_Education  G1  ...  JobDemand_Workload  JobDemand_Emo  \
# 0                  4   2  ...                  12             20
# 1                  3   5  ...                  13             18
# 2                  3   3  ...                  20             18
# 3                  3   4  ...                  17             20
# 4                  3   5  ...                  13             19
#
#    JobDemand_Cog  JOB_DEMAND  JobInsecurity_Imp  JobInsecurity_Prob  \
# 0             17          49                 27                  31
# 1              7          38                 43                  30
# 2              9          47                 43                  45
# 3             13          50                 36                  25
# 4             25          57                 13                  21
#
#    JOB_INSECURITY  Level_Presenteesim  Level_JobDemand  Level_JobInsecurity
# 0              58              Medium           Medium               Medium
# 1              73              Medium              Low                 High
# 2              88              Medium           Medium                 High
# 3              61              Medium           Medium               Medium
# 4              34                High           Medium                  Low
#
# [5 rows x 65 columns]

# %%
data["Level_Presenteesim"].unique()
# Out:
# array(['Medium', 'High', 'Low'], dtype=object)

# %%
# Mapping 0-Low, 1-Medium, 2-High

def level(l):
    if(l=="Low"):
        return 0
    elif(l=="Medium"):
        return 1
    else:
        return 2
    
data["Level_Presenteesim"] = data["Level_Presenteesim"].apply(level)

# %%
data.head()
# Out:
#    ID  Gender  Age_Group  Age  Marital_Status  Race  Religion  Tenure  \
# 0  A1       1        2.0   28               2     1         1       2
# 1  A2       2        1.0   25               2     1         1       2
# 2  A3       1        2.0   28               2     1         1       2
# 3  A4       2        2.0   30               2     1         1       3
# 4  A5       2        2.0   33               2     1         1       2
#
#    Highest_Education  G1  ...  JobDemand_Workload  JobDemand_Emo  \
# 0                  4   2  ...                  12             20
# 1                  3   5  ...                  13             18
# 2                  3   3  ...                  20             18
# 3                  3   4  ...                  17             20
# 4                  3   5  ...                  13             19
#
#    JobDemand_Cog  JOB_DEMAND  JobInsecurity_Imp  JobInsecurity_Prob  \
# 0             17          49                 27                  31
# 1              7          38                 43                  30
# 2              9          47                 43                  45
# 3             13          50                 36                  25
# 4             25          57                 13                  21
#
#    JOB_INSECURITY  Level_Presenteesim  Level_JobDemand  Level_JobInsecurity
# 0              58                   1           Medium               Medium
# 1              73                   1              Low                 High
# 2              88                   1           Medium                 High
# 3              61                   1           Medium               Medium
# 4              34                   2           Medium                  Low
#
# [5 rows x 65 columns]

# %%
corr = data.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
sns.set_theme(style="whitegrid")
sns.relplot(x=data["JOB_DEMAND"],y=data["Level_Presenteesim"], data=data);
